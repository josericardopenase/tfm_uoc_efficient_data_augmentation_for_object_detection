# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "mistralai/Mistral-7B-Instruct-v0.2"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    device_map="cuda:1",
)

inputs = tokenizer(
    "Explain quantum mechanics clearly and concisely.",
    return_tensors="pt"
).to(model.device)

out = model.generate(**inputs, max_new_tokens=150)
print(tokenizer.decode(out[0], skip_special_tokens=True))

# %%
import pandas as pd
from tqdm import tqdm
import itertools

df = pd.DataFrame({
    "prompt": [],
    "class": [],
    "environment": [],
    "style": [],
    "amount": []
})


environments = [
    "living room",
    "bedroom",
    "kitchen",
    "bathroom",
    "dining room",
    "garage",
    "home office",
    "balcony",
    "hallway",
    "laundry room",
    "basement",
    "garden",
    "patio"
]


styles = [
    "modern",
    "minimalist",
    "rustic",
    "industrial",
    "luxury",
    "vintage",
    "scandinavian",
    "messy",
    "clean",
    "cozy"
]


classes = [
    "laptop",
    "wardrobe",
    "window",
    "door",
    "potted plant",
    "photo frame",

]

amounts = [
    "Single",
    "Two",
    "Three",
    "Multiple",
]

total = len(classes) * len(environments) * len(styles) * len(amounts)
print(total)
exit

for label, env, style, amount in tqdm(
        itertools.product(classes, environments, styles, amounts),
        total=total
    ):

    prompt_text = (
        f"You are a prompt generator. The prompt must be for an amount {amount} "
        f"of a {label} in the {env} with a {style} style, "
        f"dont add tags, just the text prompt. Example: Three chairs in a cozy living room with a modern style. "
        f"Dont add verbs like create, just descriptions. "
        f"JUST OUTPUT THE PROMPT. ALWAYS USE THE WORD {label}. BE AS BRIEF AS POSSIBLE."
    )

    inputs = tokenizer(prompt_text, return_tensors="pt").to(model.device)
    output_ids = model.generate(**inputs, max_new_tokens=50)

    generated_ids = output_ids[0][inputs["input_ids"].shape[-1]:]
    text = tokenizer.decode(generated_ids, skip_special_tokens=True)

    df.loc[len(df)] = [text, label, env, style, amount]
    df.to_csv("home_objects_prompt_2.csv", index=False)
# Out:
# 3120
#   0%|          | 0/3120 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 79
#      66 for label, env, style, amount in tqdm(
#      67         itertools.product(classes, environments, styles, amounts),
#      68         total=total
#      69     ):
#      71     prompt_text = (
#      72         f"You are a prompt generator. The prompt must be for an amount {amount} "
#      73         f"of a {label} in the {env} with a {style} style, "
#    (...)     76         f"JUST OUTPUT THE PROMPT. ALWAYS USE THE WORD {label}. BE AS BRIEF AS POSSIBLE."
#      77     )
# ---> 79     inputs = tokenizer(prompt_text, return_tensors="pt").to(model.device)
#      80     output_ids = model.generate(**inputs, max_new_tokens=50)
#      82     generated_ids = output_ids[0][inputs["input_ids"].shape[-1]:]
#
# NameError: name 'tokenizer' is not defined

# %%
import pandas as pd
from tqdm import tqdm
import itertools

df = pd.DataFrame({
    "prompt": [],
    "class": [],
    "environment": [],
    "weather": [],
    "amount": []
})

# Updated environments for African wildlife
environments = [
    "savannah",
    "grassland",
    "watering hole",
    "riverbank",
    "forest",
    "jungle clearing",
    "dry plains",
    "wetlands",
    "bushland",
    "national park",
    "open plains",
    "near acacia trees",
    "muddy river",
    "dusty trail"
]

weathers = [
    "sunny",
    "cloudy",
    "rainy",
    "stormy",
    "foggy",
    "windy",
    "clear",
    "dry season",
    "wet season"
]

classes = [
    "buffalo",
    "elephant",
    "rhino",
    "zebra"
]

amounts = [
    "Single",
    "Two",
    "Three",
    "Multiple",
]

total = len(classes) * len(environments) * len(weathers) * len(amounts)
print(total)
exit

for label, env, weather, amount in tqdm(
        itertools.product(classes, environments, weathers, amounts),
        total=total
    ):

    prompt_text = (
        f"You are a prompt generator. The prompt must be for an amount {amount} "
        f"of a {label} in the {env} with a weather like {weather}, "
        f"dont add tags, just the text prompt. Example: Three elephants in a "
        f"beautiful savannah during a storm. Dont add verbs like create, just descriptions. "
        f"JUST OUTPUT THE PROMPT. ALWAYS USE THE WORD {label}. BE AS BRIEF AS POSSIBLE."
    )

    inputs = tokenizer(prompt_text, return_tensors="pt").to(model.device)
    output_ids = model.generate(**inputs, max_new_tokens=50)

    generated_ids = output_ids[0][inputs["input_ids"].shape[-1]:]
    text = tokenizer.decode(generated_ids, skip_special_tokens=True)

    df.loc[len(df)] = [text, label, env, weather, amount]
    df.to_csv("african_wildlife_prompts.csv", index=False)
# Out:
# 2016
#   0%|          | 0/2016 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 1/2016 [00:00<31:59,  1.05it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 2/2016 [00:01<31:10,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 3/2016 [00:02<27:31,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 4/2016 [00:03<34:37,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 5/2016 [00:04<33:50,  1.01s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 6/2016 [00:05<31:25,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 7/2016 [00:06<30:29,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 8/2016 [00:07<32:15,  1.04it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 9/2016 [00:08<31:41,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   0%|          | 10/2016 [00:09<30:08,  1.11it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 11/2016 [00:10<28:30,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 12/2016 [00:11<31:56,  1.05it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 13/2016 [00:12<30:54,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 14/2016 [00:12<29:37,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 15/2016 [00:13<28:10,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 16/2016 [00:14<29:22,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 17/2016 [00:15<30:13,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 18/2016 [00:16<29:07,  1.14it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 19/2016 [00:17<28:55,  1.15it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 20/2016 [00:18<31:00,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 21/2016 [00:19<31:20,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 22/2016 [00:20<30:27,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 23/2016 [00:21<30:22,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 24/2016 [00:22<32:00,  1.04it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|          | 25/2016 [00:22<30:55,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|▏         | 26/2016 [00:23<29:35,  1.12it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|▏         | 27/2016 [00:24<29:14,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|▏         | 28/2016 [00:25<31:11,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|▏         | 29/2016 [00:26<30:52,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   1%|▏         | 30/2016 [00:27<30:05,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 31/2016 [00:28<28:59,  1.14it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 32/2016 [00:29<30:26,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 33/2016 [00:30<30:20,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 34/2016 [00:31<29:42,  1.11it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 35/2016 [00:31<28:43,  1.15it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 36/2016 [00:33<31:19,  1.05it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 37/2016 [00:33<30:23,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 38/2016 [00:34<29:10,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 39/2016 [00:35<27:46,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 40/2016 [00:36<30:38,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 41/2016 [00:37<31:32,  1.04it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 42/2016 [00:38<29:25,  1.12it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 43/2016 [00:39<27:54,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 44/2016 [00:40<30:43,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 45/2016 [00:41<29:55,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 46/2016 [00:41<27:09,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 47/2016 [00:42<25:46,  1.27it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 48/2016 [00:43<30:18,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 49/2016 [00:44<30:43,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   2%|▏         | 50/2016 [00:45<28:49,  1.14it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 51/2016 [00:46<28:34,  1.15it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 52/2016 [00:47<33:53,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 53/2016 [00:48<34:18,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 54/2016 [00:49<31:18,  1.04it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 55/2016 [00:50<29:45,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 56/2016 [00:51<29:12,  1.12it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 57/2016 [00:52<29:54,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 58/2016 [00:52<28:46,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 59/2016 [00:53<27:24,  1.19it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 60/2016 [00:54<30:17,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 61/2016 [00:55<29:33,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         | 62/2016 [00:56<27:56,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#   3%|▎         |