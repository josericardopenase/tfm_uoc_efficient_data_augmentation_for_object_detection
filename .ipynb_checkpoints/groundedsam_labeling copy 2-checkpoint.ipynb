# %%
# transformers v5: restore head masks + fix attention mask API for IDEA Grounding DINO
from pathlib import Path
import sys

_pr = Path(".").resolve()
if str(_pr) not in sys.path:
    sys.path.insert(0, str(_pr))
import groundingdino_transformers_compat
groundingdino_transformers_compat.apply()

import os

# Antes de cargar el modelo: fija la GPU (solo afecta si se ejecuta antes de importar CUDA)
os.environ.setdefault("CUDA_VISIBLE_DEVICES", "0")

import pandas as pd
from tqdm import tqdm
from autodistill_grounded_sam import GroundedSAM
from autodistill.detection import CaptionOntology

DATASET_PATH = "./datasets/sAFRICANWILDLIFE_FLUXFP8"
df = pd.read_csv(f"{DATASET_PATH}/prompts.csv")
df = df[df["class"] != 'misc']

# Orden fijo de clases en los .txt (YOLO): una entrada por clase del dataset
ALL_CLASSES = sorted(df["class"].unique())
CLASS_TO_ID = {c: i for i, c in enumerate(ALL_CLASSES)}

# Ontología dummy; en el bucle se asigna la ontología por imagen
model = GroundedSAM(ontology=CaptionOntology({"init": "init"}))

print(f"Clases ({len(ALL_CLASSES)}): {ALL_CLASSES}")
print(f"Filas / imágenes: {len(df)}")
# Out:
# trying to load grounding dino directly
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
# final text_encoder_type: bert-base-uncased
# '[Errno -3] Temporary failure in name resolution' thrown while requesting HEAD https://huggingface.co/bert-base-uncased/resolve/main/adapter_config.json
# Retrying in 1s [Retry 1/5].
# downloading dino model weights
# final text_encoder_type: bert-base-uncased

# %% [markdown]
# Por cada fila se usa **`row["class"]`** como clase YOLO en el `.txt` (índice según `ALL_CLASSES`). El texto que ve Grounding DINO es `grounding_prompt_for(clase)` (p. ej. varias clases de barco → `"boat"`). No uses una lista fija tipo `ONTOLOGY_CLASSES = ["car"]`: con un solo prompt, `class_id` siempre es `0` y todas las cajas se etiquetaban mal.

# %%
import pandas as pd
from tqdm import tqdm
from autodistill_grounded_sam import GroundedSAM
from autodistill.detection import CaptionOntology

classes_dict ={}
# Orden fijo de clases en los .txt (YOLO): una entrada por clase del dataset
ALL_CLASSES = ['tugboat']
CLASS_TO_ID = {
    "tugboat" : 5
}

for x in ALL_CLASSES:
    classes_dict[x] = x






# Clase que guardas en el label → texto que usa GroundingDINO (p. ej. "person" detecta mejor)
GROUNDING_PROMPT_BY_CLASS = {
    "pedestrian": "person",
    "Person_sitting": "person",
    "person_sitting": "person",
    'cruise ship': 'boat',
 'fishing boat': 'boat',
 'human powered boat': 'boat',
 'industrial ship': 'boat',
 'jetski': 'boat',
 'military_ship': 'boat',
 'passenger ship': 'boat',
 'pedal boat': 'boat',
 'sailboat': 'boat',
 'small boat': 'boat',
 'speed_boat': 'boat',
 'tugboat': 'boat'
}

DATASET_PATH = "./datasets/sFERNANDO_TUGBOATS_FLUXDEV"
def grounding_prompt_for(label: str) -> str:
    return GROUNDING_PROMPT_BY_CLASS.get(label, GROUNDING_PROMPT_BY_CLASS.get(label.lower(), label))
# Out:
# FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers

# %%
import cv2
import supervision as sv
import json
import numpy as np
import pandas as pd
from datetime import datetime
import os

path = DATASET_PATH
output_path = os.path.join(path, "labels")
labeled_images_dir = os.path.join(path, "images_label")
json_dir = os.path.join(path, "detections_json")
os.makedirs(output_path, exist_ok=True)
os.makedirs(labeled_images_dir, exist_ok=True)
os.makedirs(json_dir, exist_ok=True)

box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()

# Prefer explicit image id from CSV (`Unnamed: 0`) if present — matches `images/{id}.png`
_ID_COL = "Unnamed: 0"
df = pd.read_csv(f"{DATASET_PATH}/prompts.csv")

def row_image_id(index, row) -> int:
    if _ID_COL in row.index:
        return int(row[_ID_COL])
    return int(index)


for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing"):
    try:
        img_id = row_image_id(index, row)
        gt_class = str(row["class"])
        grounding_prompt = grounding_prompt_for(gt_class)

        # prompt sent to Grounding DINO → canonical class stored on detections
        model.ontology = CaptionOntology({grounding_prompt: gt_class})

        image_path = os.path.join(path, "images", f"{img_id}.jpg")
        image = cv2.imread(image_path)
        if image is None:
            raise FileNotFoundError(f"No se pudo leer: {image_path}")

        h, w = image.shape[:2]
        txt_path = os.path.join(output_path, f"{img_id}.txt")

        detections = model.predict(image_path)
        detections = detections.with_nms()

        yolo_class_id = CLASS_TO_ID[gt_class]

        record = {
            "index": img_id,
            "dataframe_iter_index": int(index) if isinstance(index, (int, np.integer)) else index,
            "image_path": image_path,
            "image_width": w,
            "image_height": h,
            "ground_truth_class": gt_class,
            "grounding_prompt": grounding_prompt,
            "timestamp": datetime.now().isoformat(),
            "num_detections": len(detections) if detections is not None else 0,
            "detections": [],
        }

        # One GT class per image row; every box is written with CLASS_TO_ID[gt_class]
        if len(detections) > 0 and detections.xyxy is not None and len(detections.xyxy) > 0:
            confidences = detections.confidence if detections.confidence is not None else np.zeros(len(detections.xyxy))
            vis_labels = [f"{gt_class} {float(conf):.2f}" for conf in confidences]

            for i, (box, conf) in enumerate(zip(detections.xyxy, confidences)):
                x_min, y_min, x_max, y_max = box
                x_center = ((x_min + x_max) / 2) / w
                y_center = ((y_min + y_max) / 2) / h
                bw = (x_max - x_min) / w
                bh = (y_max - y_min) / h

                record["detections"].append({
                    "detection_id": i,
                    "class_name": gt_class,
                    "yolo_class_id": yolo_class_id,
                    "confidence": float(conf),
                    "bbox_xyxy": [float(x_min), float(y_min), float(x_max), float(y_max)],
                    "bbox_yolo": [float(x_center), float(y_center), float(bw), float(bh)],
                    "bbox_width_px": float(x_max - x_min),
                    "bbox_height_px": float(y_max - y_min),
                })

            with open(os.path.join(json_dir, f"{img_id}.json"), "w") as jf:
                json.dump(record, jf, indent=2)

            annotated_image = box_annotator.annotate(scene=image.copy(), detections=detections)
            annotated_image = label_annotator.annotate(
                scene=annotated_image,
                detections=detections,
                labels=vis_labels,
            )

            with open(txt_path, "w") as f:
                for box in detections.xyxy:
                    x_min, y_min, x_max, y_max = box
                    x_center = ((x_min + x_max) / 2) / w
                    y_center = ((y_min + y_max) / 2) / h
                    bw = (x_max - x_min) / w
                    bh = (y_max - y_min) / h
                    f.write(f"{yolo_class_id} {x_center} {y_center} {bw} {bh}\n")
        else:
            with open(os.path.join(json_dir, f"{img_id}.json"), "w") as jf:
                json.dump(record, jf, indent=2)
            annotated_image = image.copy()
            open(txt_path, "w").close()

        cv2.imwrite(os.path.join(labeled_images_dir, f"{img_id}.png"), annotated_image)

    except Exception as err:
        try:
            _iid = row_image_id(index, row)
        except Exception:
            _iid = None
        print(f"Error index={index} img_id={_iid}: {err}")
# Out:
# Processing:  25%|██▌       | 2319/9216 [00:00<00:00, 11743.26it/s]
# Error index=0 img_id=0: name 'model' is not defined
# Error index=1 img_id=1: name 'model' is not defined
# Error index=2 img_id=2: name 'model' is not defined
# Error index=3 img_id=3: name 'model' is not defined
# Error index=4 img_id=4: name 'model' is not defined
# Error index=5 img_id=5: name 'model' is not defined
# Error index=6 img_id=6: name 'model' is not defined
# Error index=7 img_id=7: name 'model' is not defined
# Error index=8 img_id=8: name 'model' is not defined
# Error index=9 img_id=9: name 'model' is not defined
# Error index=10 img_id=10: name 'model' is not defined
# Error index=11 img_id=11: name 'model' is not defined
# Error index=12 img_id=12: name 'model' is not defined
# Error index=13 img_id=13: name 'model' is not defined
# Error index=14 img_id=14: name 'model' is not defined
# Error index=15 img_id=15: name 'model' is not defined
# Error index=16 img_id=16: name 'model' is not defined
# Error index=17 img_id=17: name 'model' is not defined
# Error index=18 img_id=18: name 'model' is not defined
# Error index=19 img_id=19: name 'model' is not defined
# Error index=20 img_id=20: name 'model' is not defined
# Error index=21 img_id=21: name 'model' is not defined
# Error index=22 img_id=22: name 'model' is not defined
# Error index=23 img_id=23: name 'model' is not defined
# Error index=24 img_id=24: name 'model' is not defined
# Error index=25 img_id=25: name 'model' is not defined
# Error index=26 img_id=26: name 'model' is not defined
# Error index=27 img_id=27: name 'model' is not defined
# Error index=28 img_id=28: name 'model' is not defined
# Error index=29 img_id=29: name 'model' is not defined
# Error index=30 img_id=30: name 'model' is not defined
# Error index=31 img_id=31: name 'model' is not defined
# Error index=32 img_id=32: name 'model' is not defined
# Error index=33 img_id=33: name 'model' is not defined
# Error index=34 img_id=34: name 'model' is not defined
# Error index=35 img_id=35: name 'model' is not defined
# Error index=36 img_id=36: name 'model' is not defined
# Error index=37 img_id=37: name 'model' is not defined
# Error index=38 img_id=38: name 'model' is not defined
# Error index=39 img_id=39: name 'model' is not defined
# Error index=40 img_id=40: name 'model' is not defined
# Error index=41 img_id=41: name 'model' is not defined
# Error index=42 img_id=42: name 'model' is not defined
# Error index=43 img_id=43: name 'model' is not defined
# Error index=44 img_id=44: name 'model' is not defined
# Error index=45 img_id=45: name 'model' is not defined
# Error index=46 img_id=46: name 'model' is not defined
# Error index=47 img_id=47: name 'model' is not defined
# Error index=48 img_id=48: name 'model' is not defined
# Error index=49 img_id=49: name 'model' is not defined
# Error index=50 img_id=50: name 'model' is not defined
# Error index=51 img_id=51: name 'model' is not defined
# Error index=52 img_id=52: name 'model' is not defined
# Error index=53 img_id=53: name 'model' is not defined
# Error index=54 img_id=54: name 'model' is not defined
# Error index=55 img_id=55: name 'model' is not defined
# Error index=56 img_id=56: name 'model' is not defined
# Error index=57 img_id=57: name 'model' is not defined
# Error index=58 img_id=58: name 'model' is not defined
# Error index=59 img_id=59: name 'model' is not defined
# Error index=60 img_id=60: name 'model' is not defined
# Error index=61 img_id=61: name 'model' is not defined
# Error index=62 img_id=62: name 'model' is not defined
# Error index=63 img_id=63: name 'model' is not defined
# Error index=64 img_id=64: name 'model' is not defined
# Error index=65 img_id=65: name 'model' is not defined
# Error index=66 img_id=66: name 'model' is not defined
# Error index=67 img_id=67: name 'model' is not defined
# Error index=68 img_id=68: name 'model' is not defined
# Error index=69 img_id=69: name 'model' is not defined
# Error index=70 img_id=70: name 'model' is not defined
# Error index=71 img_id=71: name 'model' is not defined
# Error index=72 img_id=72: name 'model' is not defined
# Error index=73 img_id=73: name 'model' is not defined
# Error index=74 img_id=74: name 'model' is not defined
# Error index=75 img_id=75: name 'model' is not defined
# Error index=76 img_id=76: name 'model' is not defined
# Error index=77 img_id=77: name 'model' is not defined
# Error index=78 img_id=78: name 'model' is not defined
# Error index=79 img_id=79: name 'model' is not defined
# Error index=80 img_id=80: name 'model' is not defined
# Error index=81 img_id=81: name 'model' is not defined
# Error index=82 img_id=82: name 'model' is not defined
# Error index=83 img_id=83: name 'model' is not defined
# Error index=84 img_id=84: name 'model' is not defined
# Error index=85 img_id=85: name 'model' is not defined
# Error index=86 img_id=86: name 'model' is not defined
# Error index=87 img_id=87: name 'model' is not defined
# Error index=88 img_id=88: name 'model' is not defined
# Error index=89 img_id=89: name 'model' is not defined
# Error index=90 img_id=90: name 'model' is not defined
# Error index=91 img_id=91: name 'model' is not defined
# Error index=92 img_id=92: name 'model' is not defined
# Error index=93 img_id=93: name 'model' is not defined
# Error index=94 img_id=94: name 'model' is not defined
# Error index=95 img_id=95: name 'model' is not defined
# Error index=96 img_id=96: name 'model' is not defined
# Error index=97 img_id=97: name 'model' is not defined
# Error index=98 img_id=98: name 'model' is not defined
# Error index=99 img_id=99: name 'model' is not defined
# Error index=100 img_id=100: name 'model' is not defined
# Error index=101 img_id=101: name 'model' is not defined
# Error index=102 img_id=102: name 'model' is not defined
# Error index=103 img_id=103: name 'model' is not defined
# Error index=104 img_id=104: name 'model' is not defined
# Error index=105 img_id=105: name 'model' is not defined
# Error index=106 img_id=106: name 'model' is not defined
# Error index=107 img_id=107: name 'model' is not defined
# Error index=108 img_id=108: name 'model' is not defined
# Error index=109 img_id=109: name 'model' is not defined
# Error index=110 img_id=110: name 'model' is not defined
# Error index=111 img_id=111: name 'model' is not defined
# Error index=112 img_id=112: name 'model' is not defined
# Error index=113 img_id=113: name 'model' is not defined
# Error index=114 img_id=114: name 'model' is not defined
# Error index=115 img_id=115: name 'model' is not defined
# Error index=116 img_id=116: name 'model' is not defined
# Error index=117 img_id=117: name 'model' is not defined
# Error index=118 img_id=118: name 'model' is not defined
# Error index=119 img_id=119: name 'model' is not defined
# Error index=120 img_id=120: name 'model' is not defined
# Error index=121 img_id=121: name 'model' is not defined
# Error index=122 img_id=122: name 'model' is not defined
# Error index=123 img_id=123: name 'model' is not defined
# Error index=124 img_id=124: name 'model' is not defined
# Error index=125 img_id=125: name 'model' is not defined
# Error index=126 img_id=126: name 'model' is not defined
# Error index=127 img_id=127: name 'model' is not defined
# Error index=128 img_id=128: name 'model' is not defined
# Error index=129 img_id=129: name 'model' is not defined
# Error index=130 img_id=130: name 'model' is not defined
# Error index=131 img_id=131: name 'model' is not defined
# Error index=132 img_id=132: name 'model' is not defined
# Error index=133 img_id=133: name 'model' is not defined
# Error index=134 img_id=134: name 'model' is not defined
# Error index=135 img_id=135: name 'model' is not defined
# Error index=136 img_id=136: name 'model' is not defined
# Error index=137 img_id=137: name 'model' is not defined
# Error index=138 img_id=138: name 'model' is not defined
# Error index=139 img_id=139: name 'model' is not defined
# Error index=140 img_id=140: name 'model' is not defined
# Error index=141 img_id=141: name 'model' is not defined
# Error index=142 img_id=142: name 'model' is not defined
# Error index=143 img_id=143: name 'model' is not defined
# Error index=144 img_id=144: name 'model' is not defined
# Error index=145 img_id=145: name 'model' is not defined
# Error index=146 img_id=146: name 'model' is not defined
# Error index=147 img_id=147: name 'model' is not defined
# Error index=148 img_id=148: name 'model' is not defined
# Error index=149 img_id=149: name 'model' is not defined
# Error index=150 img_id=150: name 'model' is not defined
# Error index=151 img_id=151: name 'model' is not defined
# Error index=152 img_id=152: name 'model' is not defined
# Error index=153 img_id=153: name 'model' is not defined
# Error index=154 img_id=154: name 'model' is not defined
# Error index=155 img_id=155: name 'model' is not defined
# Error index=156 img_id=156: name 'model' is not defined
# Error index=157 img_id=157: name 'model' is not defined
# Error index=158 img_id=158: name 'model' is not defined
# Error index=159 img_id=159: name 'model' is not defined
# Error index=160 img_id=160: name 'model' is not defined
# Error index=161 img_id=161: name 'model' is not defined
# Error index=162 img_id=162: name 'model' is not defined
# Error index=163 img_id=163: name 'model' is not defined
# Error index=164 img_id=164: name 'model' is not defined
# Error index=165 img_id=165: name 'model' is not defined
# Error index=166 img_id=166: name 'model' is not defined
# Error index=167 img_id=167: name 'model' is not defined
# Error index=168 img_id=168: name 'model' is not defined
# Error index=169 img_id=169: name 'model' is not defined
# Error index=170 img_id=170: name 'model' is not defined
# Error index=171 img_id=171: name 'model' is not defined
# Error index=172 img_id=172: name 'model' is not defined
# Error index=173 img_id=173: name 'model' is not defined
# Error index=174 img_id=174: name 'model' is not defined
# Error index=175 img_id=175: name 'model' is not defined
# Error index=176 img_id=176: name 'model' is not defined
# Error index=177 img_id=177: name 'model' is not defined
# Error index=178 img_id=178: name 'model' is not defined
# Error index=179 img_id=179: name 'model' is not defined
# Error index=180 img_id=180: name 'model' is not defined
# Error index=181 img_id=181: name 'model' is not defined
# Error index=182 img_id=182: name 'model' is not defined
# Error index=183 img_id=183: name 'model' is not defined
# Error index=184 img_id=184: name 'model' is not defined
# Error index=185 img_id=185: name 'model' is not defined
# Error index=186 img_id=186: name 'model' is not defined
# Error index=187 img_id=187: name 'model' is not defined
# Error index=188 img_id=188: name 'model' is not defined
# Error index=189 img_id=189: name 'model' is not defined
# Error index=190 img_id=190: name 'model' is not defined
# Error index=191 img_id=191: name 'model' is not defined
# Error index=192 img_id=192: name 'model' is not defined
# Error index=193 img_id=193: name 'model' is not defined
# Error index=194 img_id=194: name 'model' is not defined
# Error index=195 img_id=195: name 'model' is not defined
# Error index=196 img_id=196: name 'model' is not defined
# Error index=197 img_id=197: name 'model' is not defined
# Error index=198 img_id=198: name 'model' is not defined
# Error index=199 img_id=199: name 'model' is not defined
# Error index=200 img_id=200: name 'model' is not defined
# Error index=201 img_id=201: name 'model' is not defined
# Error index=202 img_id=202: name 'model' is not defined
# Error index=203 img_id=203: name 'model' is not defined
# Error index=204 img_id=204: name 'model' is not defined
# Error index=205 img_id=205: name 'model' is not defined
# Error index=206 img_id=206: name 'model' is not defined
# Error index=207 img_id=207: name 'model' is not defined
# Error index=208 img_id=208: name 'model' is not defined
# Error index=209 img_id=209: name 'model' is not defined
# Error index=210 img_id=210: name 'model' is not defined
# Error index=211 img_id=211: name 'model' is not defined
# Error index=212 img_id=212: name 'model' is not defined
# Error index=213 img_id=213: name 'model' is not defined
# Error index=214 img_id=214: name 'model' is not defined
# Error index=215 img_id=215: name 'model' is not defined
# Error index=216 img_id=216: name 'model' is not defined
# Error index=217 img_id=217: name 'model' is not defined
# Error index=218 img_id=218: name 'model' is not defined
# Error index=219 img_id=219: name 'model' is not defined
# Error index=220 img_id=220: name 'model' is not defined
# Error index=221 img_id=221: name 'model' is not defined
# Error index=222 img_id=222: name 'model' is not defined
# Error index=223 img_id=223: name 'model' is not defined
# Error index=224 img_id=224: name 'model' is not defined
# Error index=225 img_id=225: name 'model' is not defined
# Error index=226 img_id=226: name 'model' is not defined
# Error index=227 img_id=227: name 'model' is not defined
# Error index=228 img_id=228: name 'model' is not defined
# Error index=229 img_id=229: name 'model' is not defined
# Error index=230 img_id=230: name 'model' is not defined
# Error index=231 img_id=231: name 'model' is not defined
# Error index=232 img_id=232: name 'model' is not defined
# Error index=233 img_id=233: name 'model' is not defined
# Error index=234 img_id=234: name 'model' is not defined
# Error index=235 img_id=235: name 'model' is not defined
# Error index=236 img_id=236: name 'model' is not defined
# Error index=237 img_id=237: name 'model' is not defined
# Error index=238 img_id=238: name 'model' is not defined
# Error index=239 img_id=239: name 'model' is not defined
# Error index=240 img_id=240: name 'model' is not defined
# Error index=241 img_id=241: name 'model' is not defined
# Error index=242 img_id=242: name 'model' is not defined
# Error index=243 img_id=243: name 'model' is not defined
# Error index=244 img_id=244: name 'model' is not defined
# Error index=245 img_id=245: name 'model' is not defined
# Error index=246 img_id=246: name 'model' is not defined
# Error index=247 img_id=247: name 'model' is not defined
# Error index=248 img_id=248: name 'model' is not defined
# Error index=249 img_id=249: name 'model' is not defined
# Error index=250 img_id=250: name 'model' is not defined
# Error index=251 img_id=251: name 'model' is not defined
# Error index=252 img_id=252: name 'model' is not defined
# Error index=253 img_id=253: name 'model' is not defined
# Error index=254 img_id=254: name 'model' is not defined
# Error index=255 img_id=255: name 'model' is not defined
# Error index=256 img_id=256: name 'model' is not defined
# Error index=257 img_id=257: name 'model' is not defined
# Error index=258 img_id=258: name 'model' is not defined
# Error index=259 img_id=259: name 'model' is not defined
# Error index=260 img_id=260: name 'model' is not defined
# Error index=261 img_id=261: name 'model' is not defined
# Error index=262 img_id=262: name 'model' is not defined
# Error index=263 img_id=263: name 'model' is not defined
# Error index=264 img_id=264: name 'model' is not defined
# Error index=265 img_id=265: name 'model' is not defined
# Error index=266 img_id=266: name 'model' is not defined
# Error index=267 img_id=267: name 'model' is not defined
# Error index=268 img_id=268: name 'model' is not defined
# Error index=269 img_id=269: name 'model' is not defined
# Error index=270 img_id=270: name 'model' is not defined
# Error index=271 img_id=271: name 'model' is not defined
# Error index=272 img_id=272: name 'model' is not defined
# Error index=273 img_id=273: name 'model' is not defined
# Error index=274 img_id=274: name 'model' is not defined
# Error index=275 img_id=275: name 'model' is not defined
# Error index=276 img_id=276: name 'model' is not defined
# Error index=277 img_id=277: name 'model' is not defined
# Error index=278 img_id=278: name 'model' is not defined
# Error index=279 img_id=279: name 'model' is not defined
# Error index=280 img_id=280: name 'model' is not defined
# Error index=281 img_id=281: name 'model' is not defined
# Error index=282 img_id=282: name 'model' is not defined
# Error index=283 img_id=283: name 'model' is not defined
# Error index=284 img_id=284: name 'model' is not defined
# Error index=285 img_id=285: name 'model' is not defined
# Error index=286 img_id=286: name 'model' is not defined
# Error index=287 img_id=287: name 'model' is not defined
# Error index=288 img_id=288: name 'model' is not defined
# Error index=289 img_id=289: name 'model' is not defined
# Error index=290 img_id=290: name 'model' is not defined
# Error index=291 img_id=291: name 'model' is not defined
# Error index=292 img_id=292: name 'model' is not defined
# Error index=293 img_id=293: name 'model' is not defined
# Error index=294 img_id=294: name 'model' is not defined
# Error index=295 img_id=295: name 'model' is not defined
# Error index=296 img_id=296: name 'model' is not defined
# Error index=297 img_id=297: name 'model' is not defined
# Error index=298 img_id=298: name 'model' is not defined
# Error index=299 img_id=299: name 'model' is not defined
# Error index=300 img_id=300: name 'model' is not defined
# Error index=301 img_id=301: name 'model' is not defined
# Error index=302 img_id=302: name 'model' is not defined
# Error index=303 img_id=303: name 'model' is not defined
# Error index=304 img_id=304: name 'model' is not defined
# Error index=305 img_id=305: name 'model' is not defined
# Error index=306 img_id=306: name 'model' is not defined
# Error index=307 img_id=307: name 'model' is not defined
# Error index=308 img_id=308: name 'model' is not defined
# Error index=309 img_id=309: name 'model' is not defined
# Error index=310 img_id=310: name 'model' is not defined
# Error index=311 img_id=311: name 'model' is not defined
# Error index=312 img_id=312: name 'model' is not defined
# Error index=313 img_id=313: name 'model' is not defined
# Error index=314 img_id=314: name 'model' is not defined
# Error index=315 img_id=315: name 'model' is not defined
# Error index=316 img_id=316: name 'model' is not defined
# Error index=317 img_id=317: name 'model' is not defined
# Error index=318 img_id=318: name 'model' is not defined
# Error index=319 img_id=319: name 'model' is not defined
# Error index=320 img_id=320: name 'model' is not defined
# Error index=321 img_id=321: name 'model' is not defined
# Error index=322 img_id=322: name 'model' is not defined
# Error index=323 img_id=323: name 'model' is not defined
# Error index=324 img_id=324: name 'model' is not defined
# Error index=325 img_id=325: name 'model' is not defined
# Error index=326 img_id=326: name 'model' is not defined
# Error index=327 img_id=327: name 'model' is not defined
# Error index=328 img_id=328: name 'model' is not defined
# Error index=329 img_id=329: name 'model' is not defined
# Error index=330 img_id=330: name 'model' is not defined
# Error index=331 img_id=331: name 'model' is not defined
# Error index=332 img_id=332: name 'model' is not defined
# Error index=333 img_id=333: name 'model' is not defined
# Error index=334 img_id=334: name 'model' is not defined
# Error index=335 img_id=335: name 'model' is not defined
# Error index=336 img_id=336: name 'model' is not defined
# Error index=337 img_id=337: name 'model' is not defined
# Error index=338 img_id=338: name 'model' is not defined
# Error index=339 img_id=339: name 'model' is not defined
# Error index=340 img_id=340: name 'model' is not defined
# Error index=341 img_id=341: name 'model' is not defined
# Error index=342 img_id=342: name 'model' is not defined
# Error index=343 img_id=343: name 'model' is not defined
# Error index=344 img_id=344: name 'model' is not defined
# Error index=345 img_id=345: name 'model' is not defined
# Error index=346 img_id=346: name 'model' is not defined
# Error index=347 img_id=347: name 'model' is not defined
# Error index=348 img_id=348: name 'model' is not defined
# Error index=349 img_id=349: name 'model' is not defined
# Error index=350 img_id=350: name 'model' is not defined
# Error index=351 img_id=351: name 'model' is not defined
# Error index=352 img_id=352: name 'model' is not defined
# Error index=353 img_id=353: name 'model' is not defined
# Error index=354 img_id=354: name 'model' is not defined
# Error index=355 img_id=355: name 'model' is not defined
# Error index=356 img_id=356: name 'model' is not defined
# Error index=357 img_id=357: name 'model' is not defined
# Error index=358 img_id=358: name 'model' is not defined
# Error index=359 img_id=359: name 'model' is not defined
# Error index=360 img_id=360: name 'model' is not defined
# Error index=361 img_id=361: name 'model' is not defined
# Error index=362 img_id=362: name 'model' is not defined
# Error index=363 img_id=363: name 'model' is not defined
# Error index=364 img_id=364: name 'model' is not defined
# Error index=365 img_id=365: name 'model' is not defined
# Error index=366 img_id=366: name 'model' is not defined
# Error index=367 img_id=367: name 'model' is not defined
# Error index=368 img_id=368: name 'model' is not defined
# Error index=369 img_id=369: name 'model' is not defined
# Error index=370 img_id=370: name 'model' is not defined
# Error index=371 img_id=371: name 'model' is not defined
# Error index=372 img_id=372: name 'model' is not defined
# Error index=373 img_id=373: name 'model' is not defined
# Error index=374 img_id=374: name 'model' is not defined
# Error index=375 img_id=375: name 'model' is not defined
# Error index=376 img_id=376: name 'model' is not defined
# Error index=377 img_id=377: name 'model' is not defined
# Error index=378 img_id=378: name 'model' is not defined
# Error index=379 img_id=379: name 'model' is not defined
# Error index=380 img_id=380: name 'model' is not defined
# Error index=381 img_id=381: name 'model' is not defined
# Error index=382 img_id=382: name 'model' is not defined
# Error index=383 img_id=383: name 'model' is not defined
# Error index=384 img_id=384: name 'model' is not defined
# Error index=385 img_id=385: name 'model' is not defined
# Error index=386 img_id=386: name 'model' is not defined
# Error index=387 img_id=387: name 'model' is not defined
# Error index=388 img_id=388: name 'model' is not defined
# Error index=389 img_id=389: name 'model' is not defined
# Error index=390 img_id=390: name 'model' is not defined
# Error index=391 img_id=391: name 'model' is not defined
# Error index=392 img_id=392: name 'model' is not defined
# Error index=393 img_id=393: name 'model' is not defined
# Error index=394 img_id=394: name 'model' is not defined
# Error index=395 img_id=395: name 'model' is not defined
# Error index=396 img_id=396: name 'model' is not defined
# Error index=397 img_id=397: name 'model' is not defined
# Error index=398 img_id=398: name 'model' is not defined
# Error index=399 img_id=399: name 'model' is not defined
# Error index=400 img_id=400: name 'model' is not defined
# Error index=401 img_id=401: name 'model' is not defined
# Error index=402 img_id=402: name 'model' is not defined
# Error index=403 img_id=403: name 'model' is not defined
# Error index=404 img_id=404: name 'model' is not defined
# Error index=405 img_id=405: name 'model' is not defined
# Error index=406 img_id=406: name 'model' is not defined
# Error index=407 img_id=407: name 'model' is not defined
# Error index=408 img_id=408: name 'model' is not defined
# Error index=409 img_id=409: name 'model' is not defined
# Error index=410 img_id=410: name 'model' is not defined
# Error index=411 img_id=411: name 'model' is not defined
# Error index=412 img_id=412: name 'model' is not defined
# Error index=413 img_id=413: name 'model' is not defined
# Error index=414 img_id=414: name 'model' is not defined
# Error index=415 img_id=415: name 'model' is not defined
# Error index=416 img_id=416: name 'model' is not defined
# Error index=417 img_id=417: name 'model' is not defined
# Error index=418 img_id=418: name 'model' is not defined
# Error index=419 img_id=419: name 'model' is not defined
# Error index=420 img_id=420: name 'model' is not defined
# Error index=421 img_id=421: name 'model' is not defined
# Error index=422 img_id=422: name 'model' is not defined
# Error index=423 img_id=423: name 'model' is not defined
# Error index=424 img_id=424: name 'model' is not defined
# Error index=425 img_id=425: name 'model' is not defined
# Error index=426 img_id=426: name 'model' is not defined
# Error index=427 img_id=427: name 'model' is not defined
# Error index=428 img_id=428: name 'model' is not defined
# Error index=429 img_id=429: name 'model' is not defined
# Error index=430 img_id=430: name 'model' is not defined
# Error index=431 img_id=431: name 'model' is not defined
# Error index=432 img_id=432: name 'model' is not defined
# Error index=433 img_id=433: name 'model' is not defined
# Error index=434 img_id=434: name 'model' is not defined
# Error index=435 img_id=435: name 'model' is not defined
# Error index=436 img_id=436: name 'model' is not defined
# Error index=437 img_id=437: name 'model' is not defined
# Error index=438 img_id=438: name 'model' is not defined
# Error index=439 img_id=439: name 'model' is not defined
# Error index=440 img_id=440: name 'model' is not defined
# Error index=441 img_id=441: name 'model' is not defined
# Error index=442 img_id=442: name 'model' is not defined
# Error index=443 img_id=443: name 'model' is not defined
# Error index=444 img_id=444: name 'model' is not defined
# Error index=445 img_id=445: name 'model' is not defined
# Error index=446 img_id=446: name 'model' is not defined
# Error index=447 img_id=447: name 'model' is not defined
# Error index=448 img_id=448: name 'model' is not defined
# Error index=449 img_id=449: name 'model' is not defined
# Error index=450 img_id=450: name 'model' is not defined
# Error index=451 img_id=451: name 'model' is not defined
# Error index=452 img_id=452: name 'model' is not defined
# Error index=453 img_id=453: name 'model' is not defined
# Error index=454 img_id=454: name 'model' is not defined
# Error index=455 img_id=455: name 'model' is not defined
# Error index=456 img_id=456: name 'model' is not defined
# Error index=457 img_id=457: name 'model' is not defined
# Error index=458 img_id=458: name 'model' is not defined
# Error index=459 img_id=459: name 'model' is not defined
# Error index=460 img_id=460: name 'model' is not defined
# Error index=461 img_id=461: name 'model' is not defined
# Error index=462 img_id=462: name 'model' is not defined
# Error index=463 img_id=463: name 'model' is not defined
# Error index=464 img_id=464: name 'model' is not defined
# Error index=465 img_id=465: name 'model' is not defined
# Error index=466 img_id=466: name 'model' is not defined
# Error index=467 img_id=467: name 'model' is not defined
# Error index=468 img_id=468: name 'model' is not defined
# Error index=469 img_id=469: name 'model' is not defined
# Error index=470 img_id=470: name 'model' is not defined
# Error index=471 img_id=471: name 'model' is not defined
# Error index=472 img_id=472: name 'model' is not defined
# Error index=473 img_id=473: name 'model' is not defined
# Error index=474 img_id=474: name 'model' is not defined
# Error index=475 img_id=475: name 'model' is not defined
# Error index=476 img_id=476: name 'model' is not defined
# Error index=477 img_id=477: name 'model' is not defined
# Error index=478 img_id=478: name 'model' is not defined
# Error index=479 img_id=479: name 'model' is not defined
# Error index=480 img_id=480: name 'model' is not defined
# Error index=481 img_id=481: name 'model' is not defined
# Error index=482 img_id=482: name 'model' is not defined
# Error index=483 img_id=483: name 'model' is not defined
# Error index=484 img_id=484: name 'model' is not defined
# Error index=485 img_id=485: name 'model' is not defined
# Error index=486 img_id=486: name 'model' is not defined
# Error index=487 img_id=487: name 'model' is not defined
# Error index=488 img_id=488: name 'model' is not defined
# Error index=489 img_id=489: name 'model' is not defined
# Error index=490 img_id=490: name 'model' is not defined
# Error index=491 img_id=491: name 'model' is not defined
# Error index=492 img_id=492: name 'model' is not defined
# Error index=493 img_id=493: name 'model' is not defined
# Error index=494 img_id=494: name 'model' is not defined
# Error index=495 img_id=495: name 'model' is not defined
# Error index=496 img_id=496: name 'model' is not defined
# Error index=497 img_id=497: name 'model' is not defined
# Error index=498 img_id=498: name 'model' is not defined
# Error index=499 img_id=499: name 'model' is not defined
# Error index=500 img_id=500: name 'model' is not defined
# Error index=501 img_id=501: name 'model' is not defined
# Error index=502 img_id=502: name 'model' is not defined
# Error index=503 img_id=503: name 'model' is not defined
# Error index=504 img_id=504: name 'model' is not defined
# Error index=505 img_id=505: name 'model' is not defined
# Error index=506 img_id=506: name 'model' is not defined
# Error index=507 img_id=507: name 'model' is not defined
# Error index=508 img_id=508: name 'model' is not defined
# Error index=509 img_id=509: name 'model' is not defined
# Error index=510 img_id=510: name 'model' is not defined
# Error index=511 img_id=511: name 'model' is not defined
# Error index=512 img_id=512: name 'model' is not defined
# Error index=513 img_id=513: name 'model' is not defined
# Error index=514 img_id=514: name 'model' is not defined
# Error index=515 img_id=515: name 'model' is not defined
# Error index=516 img_id=516: name 'model' is not defined
# Error index=517 img_id=517: name 'model' is not defined
# Error index=518 img_id=518: name 'model' is not defined
# Error index=519 img_id=519: name 'model' is not defined
# Error index=520 img_id=520: name 'model' is not defined
# Error index=521 img_id=521: name 'model' is not defined
# Error index=522 img_id=522: name 'model' is not defined
# Error index=523 img_id=523: name 'model' is not defined
# Error index=524 img_id=524: name 'model' is not defined
# Error index=525 img_id=525: name 'model' is not defined
# Error index=526 img_id=526: name 'model' is not defined
# Error index=527 img_id=527: name 'model' is not defined
# Error index=528 img_id=528: name 'model' is not defined
# Error index=529 img_id=529: name 'model' is not defined
# Error index=530 img_id=530: name 'model' is not defined
# Error index=531 img_id=531: name 'model' is not defined
# Error index=532 img_id=532: name 'model' is not defined
# Error index=533 img_id=533: name 'model' is not defined
# Error index=534 img_id=534: name 'model' is not defined
# Error index=535 img_id=535: name 'model' is not defined
# Error index=536 img_id=536: name 'model' is not defined
# Error index=537 img_id=537: name 'model' is not defined
# Error index=538 img_id=538: name 'model' is not defined
# Error index=539 img_id=539: name 'model' is not defined
# Error index=540 img_id=540: name 'model' is not defined
# Error index=541 img_id=541: name 'model' is not defined
# Error index=542 img_id=542: name 'model' is not defined
# Error index=543 img_id=543: name 'model' is not defined
# Error index=544 img_id=544: name 'model' is not defined
# Error index=545 img_id=545: name 'model' is not defined
# Error index=546 img_id=546: name 'model' is not defined
# Error index=547 img_id=547: name 'model' is not defined
# Error index=548 img_id=548: name 'model' is not defined
# Error index=549 img_id=549: name 'model' is not defined
# Error index=550 img_id=550: name 'model' is not defined
# Error index=551 img_id=551: name 'model' is not defined
# Error index=552 img_id=552: name 'model' is not defined
# Error index=553 img_id=553: name 'model' is not defined
# Error index=554 img_id=554: name 'model' is not defined
# Error index=555 img_id=555: name 'model' is not defined
# Error index=556 img_id=556: name 'model' is not defined
# Error index=557 img_id=557: name 'model' is not defined
# Error index=558 img_id=558: name 'model' is not defined
# Error index=559 img_id=559: name 'model' is not defined
# Error index=560 img_id=560: name 'model' is not defined
# Error index=561 img_id=561: name 'model' is not defined
# Error index=562 img_id=562: name 'model' is not defined
# Error index=563 img_id=563: name 'model' is not defined
# Error index=564 img_id=564: name 'model' is not defined
# Error index=565 img_id=565: name 'model' is not defined
# Error index=566 img_id=566: name 'model' is not defined
# Error index=567 img_id=567: name 'model' is not defined
# Error index=568 img_id=568: name 'model' is not defined
# Error index=569 img_id=569: name 'model' is not defined
# Error index=570 img_id=570: name 'model' is not defined
# Error index=571 img_id=571: name 'model' is not defined
# Error index=572 img_id=572: name 'model' is not defined
# Error index=573 img_id=573: name 'model' is not defined
# Error index=574 img_id=574: name 'model' is not defined
# Error index=575 img_id=575: name 'model' is not defined
# Error index=576 img_id=576: name 'model' is not defined
# Error index=577 img_id=577: name 'model' is not defined
# Error index=578 img_id=578: name 'model' is not defined
# Error index=579 img_id=579: name 'model' is not defined
# Error index=580 img_id=580: name 'model' is not defined
# Error index=581 img_id=581: name 'model' is not defined
# Error index=582 img_id=582: name 'model' is not defined
# Error index=583 img_id=583: name 'model' is not defined
# Error index=584 img_id=584: name 'model' is not defined
# Error index=585 img_id=585: name 'model' is not defined
# Error index=586 img_id=586: name 'model' is not defined
# Error index=587 img_id=587: name 'model' is not defined
# Error index=588 img_id=588: name 'model' is not defined
# Error index=589 img_id=589: name 'model' is not defined
# Error index=590 img_id=590: name 'model' is not defined
# Error index=591 img_id=591: name 'model' is not defined
# Error index=592 img_id=592: name 'model' is not defined
# Error index=593 img_id=593: name 'model' is not defined
# Error index=594 img_id=594: name 'model' is not defined
# Error index=595 img_id=595: name 'model' is not defined
# Error index=596 img_id=596: name 'model' is not defined
# Error index=597 img_id=597: name 'model' is not defined
# Error index=598 img_id=598: name 'model' is not defined
# Error index=599 img_id=599: name 'model' is not defined
# Error index=600 img_id=600: name 'model' is not defined
# Error index=601 img_id=601: name 'model' is not defined
# Error index=602 img_id=602: name 'model' is not defined
# Error index=603 img_id=603: name 'model' is not defined
# Error index=604 img_id=604: name 'model' is not defined
# Error index=605 img_id=605: name 'model' is not defined
# Error index=606 img_id=606: name 'model' is not defined
# Error index=607 img_id=607: name 'model' is not defined
# Error index=608 img_id=608: name 'model' is not defined
# Error index=609 img_id=609: name 'model' is not defined
# Error index=610 img_id=610: name 'model' is not defined
# Error index=611 img_id=611: name 'model' is not defined
# Error index=612 img_id=612: name 'model' is not defined
# Error index=613 img_id=613: name 'model' is not defined
# Error index=614 img_id=614: name 'model' is not defined
# Error index=615 img_id=615: name 'model' is not defined
# Error index=616 img_id=616: name 'model' is not defined
# Error index=617 img_id=617: name 'model' is not defined
# Error index=618 img_id=618: name 'model' is not defined
# Error index=619 img_id=619: name 'model' is not defined
# Error index=620 img_id=620: name 'model' is not defined
# Error index=621 img_id=621: name 'model' is not defined
# Error index=622 img_id=622: name 'model' is not defined
# Error index=623 img_id=623: name 'model' is not defined
# Error index=624 img_id=624: name 'model' is not defined
# Error index=625 img_id=625: name 'model' is not defined
# Error index=626 img_id=626: name 'model' is not defined
# Error index=627 img_id=627: name 'model' is not defined
# Error index=628 img_id=628: name 'model' is not defined
# Error index=629 img_id=629: name 'model' is not defined
# Error index=630 img_id=630: name 'model' is not defined
# Error index=631 img_id=631: name 'model' is not defined
# Error index=632 img_id=632: name 'model' is not defined
# Error index=633 img_id=633: name 'model' is not defined
# Error index=634 img_id=634: name 'model' is not defined
# Error index=635 img_id=635: name 'model' is not defined
# Error index=636 img_id=636: name 'model' is not defined
# Error index=637 img_id=637: name 'model' is not defined
# Error index=638 img_id=638: name 'model' is not defined
# Error index=639 img_id=639: name 'model' is not defined
# Error index=640 img_id=640: name 'model' is not defined
# Error index=641 img_id=641: name 'model' is not defined
# Error index=642 img_id=642: name 'model' is not defined
# Error index=643 img_id=643: name 'model' is not defined
# Error index=644 img_id=644: name 'model' is not defined
# Error index=645 img_id=645: name 'model' is not defined
# Error index=646 img_id=646: name 'model' is not defined
# Error index=647 img_id=647: name 'model' is not defined
# Error index=648 img_id=648: name 'model' is not defined
# Error index=649 img_id=649: name 'model' is not defined
# Error index=650 img_id=650: name 'model' is not defined
# Error index=651 img_id=651: name 'model' is not defined
# Error index=652 img_id=652: name 'model' is not defined
# Error index=653 img_id=653: name 'model' is not defined
# Error index=654 img_id=654: name 'model' is not defined
# Error index=655 img_id=655: name 'model' is not defined
# Error index=656 img_id=656: name 'model' is not defined
# Error index=657 img_id=657: name 'model' is not defined
# Error index=658 img_id=658: name 'model' is not defined
# Error index=659 img_id=659: name 'model' is not defined
# Error index=660 img_id=660: name 'model' is not defined
# Error index=661 img_id=661: name 'model' is not defined
# Error index=662 img_id=662: name 'model' is not defined
# Error index=663 img_id=663: name 'model' is not defined
# Error index=664 img_id=664: name 'model' is not defined
# Error index=665 img_id=665: name 'model' is not defined
# Error index=666 img_id=666: name 'model' is not defined
# Error index=667 img_id=667: name 'model' is not defined
# Error index=668 img_id=668: name 'model' is not defined
# Error index=669 img_id=669: name 'model' is not defined
# Error index=670 img_id=670: name 'model' is not defined
# Error index=671 img_id=671: name 'model' is not defined
# Error index=672 img_id=672: name 'model' is not defined
# Error index=673 img_id=673: name 'model' is not defined
# Error index=674 img_id=674: name 'model' is not defined
# Error index=675 img_id=675: name 'model' is not defined
# Error index=676 img_id=676: name 'model' is not defined
# Error index=677 img_id=677: name 'model' is not defined
# Error index=678 img_id=678: name 'model' is not defined
# Error index=679 img_id=679: name 'model' is not defined
# Error index=680 img_id=680: name 'model' is not defined
# Error index=681 img_id=681: name 'model' is not defined
# Error index=682 img_id=682: name 'model' is not defined
# Error index=683 img_id=683: name 'model' is not defined
# Error index=684 img_id=684: name 'model' is not defined
# Error index=685 img_id=685: name 'model' is not defined
# Error index=686 img_id=686: name 'model' is not defined
# Error index=687 img_id=687: name 'model' is not defined
# Error index=688 img_id=688: name 'model' is not defined
# Error index=689 img_id=689: name 'model' is not defined
# Error index=690 img_id=690: name 'model' is not defined
# Error index=691 img_id=691: name 'model' is not defined
# Error index=692 img_id=692: name 'model' is not defined
# Error index=693 img_id=693: name 'model' is not defined
# Error index=694 img_id=694: name 'model' is not defined
# Error index=695 img_id=695: name 'model' is not defined
# Error index=696 img_id=696: name 'model' is not defined
# Error index=697 img_id=697: name 'model' is not defined
# Error index=698 img_id=698: name 'model' is not defined
# Error index=699 img_id=699: name 'model' is not defined
# Error index=700 img_id=700: name 'model' is not defined
# Error index=701 img_id=701: name 'model' is not defined
# Error index=702 img_id=702: name 'model' is not defined
# Error index=703 img_id=703: name 'model' is not defined
# Error index=704 img_id=704: name 'model' is not defined
# Error index=705 img_id=705: name 'model' is not defined
# Error index=706 img_id=706: name 'model' is not defined
# Error index=707 img_id=707: name 'model' is not defined
# Error index=708 img_id=708: name 'model' is not defined
# Error index=709 img_id=709: name 'model' is not defined
# Error index=710 img_id=710: name 'model' is not defined
# Error index=711 img_id=711: name 'model' is not defined
# Error index=712 img_id=712: name 'model' is not defined
# Error index=713 img_id=713: name 'model' is not defined
# Error index=714 img_id=714: name 'model' is not defined
# Error index=715 img_id=715: name 'model' is not defined
# Error index=716 img_id=716: name 'model' is not defined
# Error index=717 img_id=717: name 'model' is not defined
# Error index=718 img_id=718: name 'model' is not defined
# Error index=719 img_id=719: name 'model' is not defined
# Error index=720 img_id=720: name 'model' is not defined
# Error index=721 img_id=721: name 'model' is not defined
# Error index=722 img_id=722: name 'model' is not defined
# Error index=723 img_id=723: name 'model' is not defined
# Error index=724 img_id=724: name 'model' is not defined
# Error index=725 img_id=725: name 'model' is not defined
# Error index=726 img_id=726: name 'model' is not defined
# Error index=727 img_id=727: name 'model' is not defined
# Error index=728 img_id=728: name 'model' is not defined
# Error index=729 img_id=729: name 'model' is not defined
# Error index=730 img_id=730: name 'model' is not defined
# Error index=731 img_id=731: name 'model' is not defined
# Error index=732 img_id=732: name 'model' is not defined
# Error index=733 img_id=733: name 'model' is not defined
# Error index=734 img_id=734: name 'model' is not defined
# Error index=735 img_id=735: name 'model' is not defined
# Error index=736 img_id=736: name 'model' is not defined
# Error index=737 img_id=737: name 'model' is not defined
# Error index=738 img_id=738: name 'model' is not defined
# Error index=739 img_id=739: name 'model' is not defined
# Error index=740 img_id=740: name 'model' is not defined
# Error index=741 img_id=741: name 'model' is not defined
# Error index=742 img_id=742: name 'model' is not defined
# Error index=743 img_id=743: name 'model' is not defined
# Error index=744 img_id=744: name 'model' is not defined
# Error index=745 img_id=745: name 'model' is not defined
# Error index=746 img_id=746: name 'model' is not defined
# Error index=747 img_id=747: name 'model' is not defined
# Error index=748 img_id=748: name 'model' is not defined
# Error index=749 img_id=749: name 'model' is not defined
# Error index=750 img_id=750: name 'model' is not defined
# Error index=751 img_id=751: name 'model' is not defined
# Error index=752 img_id=752: name 'model' is not defined
# Error index=753 img_id=753: name 'model' is not defined
# Error index=754 img_id=754: name 'model' is not defined
# Error index=755 img_id=755: name 'model' is not defined
# Error index=756 img_id=756: name 'model' is not defined
# Error index=757 img_id=757: name 'model' is not defined
# Error index=758 img_id=758: name 'model' is not defined
# Error index=759 img_id=759: name 'model' is not defined
# Error index=760 img_id=760: name 'model' is not defined
# Error index=761 img_id=761: name 'model' is not defined
# Error index=762 img_id=762: name 'model' is not defined
# Error index=763 img_id=763: name 'model' is not defined
# Error index=764 img_id=764: name 'model' is not defined
# Error index=765 img_id=765: name 'model' is not defined
# Error index=766 img_id=766: name 'model' is not defined
# Error index=767 img_id=767: name 'model' is not defined
# Error index=768 img_id=768: name 'model' is not defined
# Error index=769 img_id=769: name 'model' is not defined
# Error index=770 img_id=770: name 'model' is not defined
# Error index=771 img_id=771: name 'model' is not defined
# Error index=772 img_id=772: name 'model' is not defined
# Error index=773 img_id=773: name 'model' is not defined
# Error index=774 img_id=774: name 'model' is not defined
# Error index=775 img_id=775: name 'model' is not defined
# Error index=776 img_id=776: name 'model' is not defined
# Error index=777 img_id=777: name 'model' is not defined
# Error index=778 img_id=778: name 'model' is not defined
# Error index=779 img_id=779: name 'model' is not defined
# Error index=780 img_id=780: name 'model' is not defined
# Error index=781 img_id=781: name 'model' is not defined
# Error index=782 img_id=782: name 'model' is not defined
# Error index=783 img_id=783: name 'model' is not defined
# Error index=784 img_id=784: name 'model' is not defined
# Error index=785 img_id=785: name 'model' is not defined
# Error index=786 img_id=786: name 'model' is not defined
# Error index=787 img_id=787: name 'model' is not defined
# Error index=788 img_id=788: name 'model' is not defined
# Error index=789 img_id=789: name 'model' is not defined
# Error index=790 img_id=790: name 'model' is not defined
# Error index=791 img_id=791: name 'model' is not defined
# Error index=792 img_id=792: name 'model' is not defined
# Error index=793 img_id=793: name 'model' is not defined
# Error index=794 img_id=794: name 'model' is not defined
# Error index=795 img_id=795: name 'model' is not defined
# Error index=796 img_id=796: name 'model' is not defined
# Error index=797 img_id=797: name 'model' is not defined
# Error index=798 img_id=798: name 'model' is not defined
# Error index=799 img_id=799: name 'model' is not defined
# Error index=800 img_id=800: name 'model' is not defined
# Error index=801 img_id=801: name 'model' is not defined
# Error index=802 img_id=802: name 'model' is not defined
# Error index=803 img_id=803: name 'model' is not defined
# Error index=804 img_id=804: name 'model' is not defined
# Error index=805 img_id=805: name 'model' is not defined
# Error index=806 img_id=806: name 'model' is not defined
# Error index=807 img_id=807: name 'model' is not defined
# Error index=808 img_id=808: name 'model' is not defined
# Error index=809 img_id=809: name 'model' is not defined
# Error index=810 img_id=810: name 'model' is not defined
# Error index=811 img_id=811: name 'model' is not defined
# Error index=812 img_id=812: name 'model' is not defined
# Error index=813 img_id=813: name 'model' is not defined
# Error index=814 img_id=814: name 'model' is not defined
# Error index=815 img_id=815: name 'model' is not defined
# Error index=816 img_id=816: name 'model' is not defined
# Error index=817 img_id=817: name 'model' is not defined
# Error index=818 img_id=818: name 'model' is not defined
# Error index=819 img_id=819: name 'model' is not defined
# Error index=820 img_id=820: name 'model' is not defined
# Error index=821 img_id=821: name 'model' is not defined
# Error index=822 img_id=822: name 'model' is not defined
# Error index=823 img_id=823: name 'model' is not defined
# Error index=824 img_id=824: name 'model' is not defined
# Error index=825 img_id=825: name 'model' is not defined
# Error index=826 img_id=826: name 'model' is not defined
# Error index=827 img_id=827: name 'model' is not defined
# Error index=828 img_id=828: name 'model' is not defined
# Error index=829 img_id=829: name 'model' is not defined
# Error index=830 img_id=830: name 'model' is not defined
# Error index=831 img_id=831: name 'model' is not defined
# Error index=832 img_id=832: name 'model' is not defined
# Error index=833 img_id=833: name 'model' is not defined
# Error index=834 img_id=834: name 'model' is not defined
# Error index=835 img_id=835: name 'model' is not defined
# Error index=836 img_id=836: name 'model' is not defined
# Error index=837 img_id=837: name 'model' is not defined
# Error index=838 img_id=838: name 'model' is not defined
# Error index=839 img_id=839: name 'model' is not defined
# Error index=840 img_id=840: name 'model' is not defined
# Error index=841 img_id=841: name 'model' is not defined
# Error index=842 img_id=842: name 'model' is not defined
# Error index=843 img_id=843: name 'model' is not defined
# Error index=844 img_id=844: name 'model' is not defined
# Error index=845 img_id=845: name 'model' is not defined
# Error index=846 img_id=846: name 'model' is not defined
# Error index=847 img_id=847: name 'model' is not defined
# Error index=848 img_id=848: name 'model' is not defined
# Error index=849 img_id=849: name 'model' is not defined
# Error index=850 img_id=850: name 'model' is not defined
# Error index=851 img_id=851: name 'model' is not defined
# Error index=852 img_id=852: name 'model' is not defined
# Error index=853 img_id=853: name 'model' is not defined
# Error index=854 img_id=854: name 'model' is not defined
# Error index=855 img_id=855: name 'model' is not defined
# Error index=856 img_id=856: name 'model' is not defined
# Error index=857 img_id=857: name 'model' is not defined
# Error index=858 img_id=858: name 'model' is not defined
# ...
# Error index=8941 img_id=8941: name 'model' is not defined
# Error index=8942 img_id=8942: name 'model' is not defined
# Error index=8943 img_id=8943: name 'model' is not defined
# Error index=8944 img_id=8944: name 'model' is not defined
# Error index=8945 img_id=8945: name 'model' is not defined
# Error index=8946 img_id=8946: name 'model' is not defined
# Error index=8947 img_id=8947: name 'model' is not defined
# Error index=8948 img_id=8948: name 'model' is not defined
# Error index=8949 img_id=8949: name 'model' is not defined
# Error index=8950 img_id=8950: name 'model' is not defined
# Error index=8951 img_id=8951: name 'model' is not defined
# Error index=8952 img_id=8952: name 'model' is not defined
# Error index=8953 img_id=8953: name 'model' is not defined
# Error index=8954 img_id=8954: name 'model' is not defined
# Error index=8955 img_id=8955: name 'model' is not defined
# Error index=8956 img_id=8956: name 'model' is not defined
# Error index=8957 img_id=8957: name 'model' is not defined
# Error index=8958 img_id=8958: name 'model' is not defined
# Error index=8959 img_id=8959: name 'model' is not defined
# Error index=8960 img_id=8960: name 'model' is not defined
# Error index=8961 img_id=8961: name 'model' is not defined
# Error index=8962 img_id=8962: name 'model' is not defined
# Error index=8963 img_id=8963: name 'model' is not defined
# Error index=8964 img_id=8964: name 'model' is not defined
# Error index=8965 img_id=8965: name 'model' is not defined
# Error index=8966 img_id=8966: name 'model' is not defined
# Error index=8967 img_id=8967: name 'model' is not defined
# Error index=8968 img_id=8968: name 'model' is not defined
# Error index=8969 img_id=8969: name 'model' is not defined
# Error index=8970 img_id=8970: name 'model' is not defined
# Error index=8971 img_id=8971: name 'model' is not defined
# Error index=8972 img_id=8972: name 'model' is not defined
# Error index=8973 img_id=8973: name 'model' is not defined
# Error index=8974 img_id=8974: name 'model' is not defined
# Error index=8975 img_id=8975: name 'model' is not defined
# Error index=8976 img_id=8976: name 'model' is not defined
# Error index=8977 img_id=8977: name 'model' is not defined
# Error index=8978 img_id=8978: name 'model' is not defined
# Error index=8979 img_id=8979: name 'model' is not defined
# Error index=8980 img_id=8980: name 'model' is not defined
# Error index=8981 img_id=8981: name 'model' is not defined
# Error index=8982 img_id=8982: name 'model' is not defined
# Error index=8983 img_id=8983: name 'model' is not defined
# Error index=8984 img_id=8984: name 'model' is not defined
# Error index=8985 img_id=8985: name 'model' is not defined
# Error index=8986 img_id=8986: name 'model' is not defined
# Error index=8987 img_id=8987: name 'model' is not defined
# Error index=8988 img_id=8988: name 'model' is not defined
# Error index=8989 img_id=8989: name 'model' is not defined
# Error index=8990 img_id=8990: name 'model' is not defined
# Error index=8991 img_id=8991: name 'model' is not defined
# Error index=8992 img_id=8992: name 'model' is not defined
# Error index=8993 img_id=8993: name 'model' is not defined
# Error index=8994 img_id=8994: name 'model' is not defined
# Error index=8995 img_id=8995: name 'model' is not defined
# Error index=8996 img_id=8996: name 'model' is not defined
# Error index=8997 img_id=8997: name 'model' is not defined
# Error index=8998 img_id=8998: name 'model' is not defined
# Error index=8999 img_id=8999: name 'model' is not defined
# Error index=9000 img_id=9000: name 'model' is not defined
# Error index=9001 img_id=9001: name 'model' is not defined
# Error index=9002 img_id=9002: name 'model' is not defined
# Error index=9003 img_id=9003: name 'model' is not defined
# Error index=9004 img_id=9004: name 'model' is not defined
# Error index=9005 img_id=9005: name 'model' is not defined
# Error index=9006 img_id=9006: name 'model' is not defined
# Error index=9007 img_id=9007: name 'model' is not defined
# Error index=9008 img_id=9008: name 'model' is not defined
# Error index=9009 img_id=9009: name 'model' is not defined
# Error index=9010 img_id=9010: name 'model' is not defined
# Error index=9011 img_id=9011: name 'model' is not defined
# Error index=9012 img_id=9012: name 'model' is not defined
# Error index=9013 img_id=9013: name 'model' is not defined
# Error index=9014 img_id=9014: name 'model' is not defined
# Error index=9015 img_id=9015: name 'model' is not defined
# Error index=9016 img_id=9016: name 'model' is not defined
# Error index=9017 img_id=9017: name 'model' is not defined
# Error index=9018 img_id=9018: name 'model' is not defined
# Error index=9019 img_id=9019: name 'model' is not defined
# Error index=9020 img_id=9020: name 'model' is not defined
# Error index=9021 img_id=9021: name 'model' is not defined
# Error index=9022 img_id=9022: name 'model' is not defined
# Error index=9023 img_id=9023: name 'model' is not defined
# Error index=9024 img_id=9024: name 'model' is not defined
# Error index=9025 img_id=9025: name 'model' is not defined
# Error index=9026 img_id=9026: name 'model' is not defined
# Error index=9027 img_id=9027: name 'model' is not defined
# Error index=9028 img_id=9028: name 'model' is not defined
# Error index=9029 img_id=9029: name 'model' is not defined
# Error index=9030 img_id=9030: name 'model' is not defined
# Error index=9031 img_id=9031: name 'model' is not defined
# Error index=9032 img_id=9032: name 'model' is not defined
# Error index=9033 img_id=9033: name 'model' is not defined
# Error index=9034 img_id=9034: name 'model' is not defined
# Error index=9035 img_id=9035: name 'model' is not defined
# Error index=9036 img_id=9036: name 'model' is not defined
# Error index=9037 img_id=9037: name 'model' is not defined
# Error index=9038 img_id=9038: name 'model' is not defined
# Error index=9039 img_id=9039: name 'model' is not defined
# Error index=9040 img_id=9040: name 'model' is not defined
# Error index=9041 img_id=9041: name 'model' is not defined
# Error index=9042 img_id=9042: name 'model' is not defined
# Error index=9043 img_id=9043: name 'model' is not defined
# Error index=9044 img_id=9044: name 'model' is not defined
# Error index=9045 img_id=9045: name 'model' is not defined
# Error index=9046 img_id=9046: name 'model' is not defined
# Error index=9047 img_id=9047: name 'model' is not defined
# Error index=9048 img_id=9048: name 'model' is not defined
# Error index=9049 img_id=9049: name 'model' is not defined
# Error index=9050 img_id=9050: name 'model' is not defined
# Error index=9051 img_id=9051: name 'model' is not defined
# Error index=9052 img_id=9052: name 'model' is not defined
# Error index=9053 img_id=9053: name 'model' is not defined
# Error index=9054 img_id=9054: name 'model' is not defined
# Error index=9055 img_id=9055: name 'model' is not defined
# Error index=9056 img_id=9056: name 'model' is not defined
# Error index=9057 img_id=9057: name 'model' is not defined
# Error index=9058 img_id=9058: name 'model' is not defined
# Error index=9059 img_id=9059: name 'model' is not defined
# Error index=9060 img_id=9060: name 'model' is not defined
# Error index=9061 img_id=9061: name 'model' is not defined
# Error index=9062 img_id=9062: name 'model' is not defined
# Error index=9063 img_id=9063: name 'model' is not defined
# Error index=9064 img_id=9064: name 'model' is not defined
# Error index=9065 img_id=9065: name 'model' is not defined
# Error index=9066 img_id=9066: name 'model' is not defined
# Error index=9067 img_id=9067: name 'model' is not defined
# Error index=9068 img_id=9068: name 'model' is not defined
# Error index=9069 img_id=9069: name 'model' is not defined
# Error index=9070 img_id=9070: name 'model' is not defined
# Error index=9071 img_id=9071: name 'model' is not defined
# Error index=9072 img_id=9072: name 'model' is not defined
# Error index=9073 img_id=9073: name 'model' is not defined
# Error index=9074 img_id=9074: name 'model' is not defined
# Error index=9075 img_id=9075: name 'model' is not defined
# Error index=9076 img_id=9076: name 'model' is not defined
# Error index=9077 img_id=9077: name 'model' is not defined
# Error index=9078 img_id=9078: name 'model' is not defined
# Error index=9079 img_id=9079: name 'model' is not defined
# Error index=9080 img_id=9080: name 'model' is not defined
# Error index=9081 img_id=9081: name 'model' is not defined
# Error index=9082 img_id=9082: name 'model' is not defined
# Error index=9083 img_id=9083: name 'model' is not defined
# Error index=9084 img_id=9084: name 'model' is not defined
# Error index=9085 img_id=9085: name 'model' is not defined
# Error index=9086 img_id=9086: name 'model' is not defined
# Error index=9087 img_id=9087: name 'model' is not defined
# Error index=9088 img_id=9088: name 'model' is not defined
# Error index=9089 img_id=9089: name 'model' is not defined
# Error index=9090 img_id=9090: name 'model' is not defined
# Error index=9091 img_id=9091: name 'model' is not defined
# Error index=9092 img_id=9092: name 'model' is not defined
# Error index=9093 img_id=9093: name 'model' is not defined
# Error index=9094 img_id=9094: name 'model' is not defined
# Error index=9095 img_id=9095: name 'model' is not defined
# Error index=9096 img_id=9096: name 'model' is not defined
# Error index=9097 img_id=9097: name 'model' is not defined
# Error index=9098 img_id=9098: name 'model' is not defined
# Error index=9099 img_id=9099: name 'model' is not defined
# Error index=9100 img_id=9100: name 'model' is not defined
# Error index=9101 img_id=9101: name 'model' is not defined
# Error index=9102 img_id=9102: name 'model' is not defined
# Error index=9103 img_id=9103: name 'model' is not defined
# Error index=9104 img_id=9104: name 'model' is not defined
# Error index=9105 img_id=9105: name 'model' is not defined
# Error index=9106 img_id=9106: name 'model' is not defined
# Error index=9107 img_id=9107: name 'model' is not defined
# Error index=9108 img_id=9108: name 'model' is not defined
# Error index=9109 img_id=9109: name 'model' is not defined
# Error index=9110 img_id=9110: name 'model' is not defined
# Error index=9111 img_id=9111: name 'model' is not defined
# Error index=9112 img_id=9112: name 'model' is not defined
# Error index=9113 img_id=9113: name 'model' is not defined
# Error index=9114 img_id=9114: name 'model' is not defined
# Error index=9115 img_id=9115: name 'model' is not defined
# Error index=9116 img_id=9116: name 'model' is not defined
# Error index=9117 img_id=9117: name 'model' is not defined
# Error index=9118 img_id=9118: name 'model' is not defined
# Error index=9119 img_id=9119: name 'model' is not defined
# Error index=9120 img_id=9120: name 'model' is not defined
# Error index=9121 img_id=9121: name 'model' is not defined
# Error index=9122 img_id=9122: name 'model' is not defined
# Error index=9123 img_id=9123: name 'model' is not defined
# Error index=9124 img_id=9124: name 'model' is not defined
# Error index=9125 img_id=9125: name 'model' is not defined
# Error index=9126 img_id=9126: name 'model' is not defined
# Error index=9127 img_id=9127: name 'model' is not defined
# Error index=9128 img_id=9128: name 'model' is not defined
# Error index=9129 img_id=9129: name 'model' is not defined
# Error index=9130 img_id=9130: name 'model' is not defined
# Error index=9131 img_id=9131: name 'model' is not defined
# Error index=9132 img_id=9132: name 'model' is not defined
# Error index=9133 img_id=9133: name 'model' is not defined
# Error index=9134 img_id=9134: name 'model' is not defined
# Error index=9135 img_id=9135: name 'model' is not defined
# Error index=9136 img_id=9136: name 'model' is not defined
# Error index=9137 img_id=9137: name 'model' is not defined
# Error index=9138 img_id=9138: name 'model' is not defined
# Error index=9139 img_id=9139: name 'model' is not defined
# Error index=9140 img_id=9140: name 'model' is not defined
# Error index=9141 img_id=9141: name 'model' is not defined
# Error index=9142 img_id=9142: name 'model' is not defined
# Error index=9143 img_id=9143: name 'model' is not defined
# Error index=9144 img_id=9144: name 'model' is not defined
# Error index=9145 img_id=9145: name 'model' is not defined
# Error index=9146 img_id=9146: name 'model' is not defined
# Error index=9147 img_id=9147: name 'model' is not defined
# Error index=9148 img_id=9148: name 'model' is not defined
# Error index=9149 img_id=9149: name 'model' is not defined
# Error index=9150 img_id=9150: name 'model' is not defined
# Error index=9151 img_id=9151: name 'model' is not defined
# Error index=9152 img_id=9152: name 'model' is not defined
# Error index=9153 img_id=9153: name 'model' is not defined
# Error index=9154 img_id=9154: name 'model' is not defined
# Error index=9155 img_id=9155: name 'model' is not defined
# Error index=9156 img_id=9156: name 'model' is not defined
# Error index=9157 img_id=9157: name 'model' is not defined
# Error index=9158 img_id=9158: name 'model' is not defined
# Error index=9159 img_id=9159: name 'model' is not defined
# Error index=9160 img_id=9160: name 'model' is not defined
# Error index=9161 img_id=9161: name 'model' is not defined
# Error index=9162 img_id=9162: name 'model' is not defined
# Error index=9163 img_id=9163: name 'model' is not defined
# Error index=9164 img_id=9164: name 'model' is not defined
# Error index=9165 img_id=9165: name 'model' is not defined
# Error index=9166 img_id=9166: name 'model' is not defined
# Error index=9167 img_id=9167: name 'model' is not defined
# Error index=9168 img_id=9168: name 'model' is not defined
# Error index=9169 img_id=9169: name 'model' is not defined
# Error index=9170 img_id=9170: name 'model' is not defined
# Error index=9171 img_id=9171: name 'model' is not defined
# Error index=9172 img_id=9172: name 'model' is not defined
# Error index=9173 img_id=9173: name 'model' is not defined
# Error index=9174 img_id=9174: name 'model' is not defined
# Error index=9175 img_id=9175: name 'model' is not defined
# Error index=9176 img_id=9176: name 'model' is not defined
# Error index=9177 img_id=9177: name 'model' is not defined
# Error index=9178 img_id=9178: name 'model' is not defined
# Error index=9179 img_id=9179: name 'model' is not defined
# Error index=9180 img_id=9180: name 'model' is not defined
# Error index=9181 img_id=9181: name 'model' is not defined
# Error index=9182 img_id=9182: name 'model' is not defined
# Error index=9183 img_id=9183: name 'model' is not defined
# Error index=9184 img_id=9184: name 'model' is not defined
# Error index=9185 img_id=9185: name 'model' is not defined
# Error index=9186 img_id=9186: name 'model' is not defined
# Error index=9187 img_id=9187: name 'model' is not defined
# Error index=9188 img_id=9188: name 'model' is not defined
# Error index=9189 img_id=9189: name 'model' is not defined
# Error index=9190 img_id=9190: name 'model' is not defined
# Error index=9191 img_id=9191: name 'model' is not defined
# Error index=9192 img_id=9192: name 'model' is not defined
# Error index=9193 img_id=9193: name 'model' is not defined
# Error index=9194 img_id=9194: name 'model' is not defined
# Error index=9195 img_id=9195: name 'model' is not defined
# Error index=9196 img_id=9196: name 'model' is not defined
# Error index=9197 img_id=9197: name 'model' is not defined
# Error index=9198 img_id=9198: name 'model' is not defined
# Error index=9199 img_id=9199: name 'model' is not defined
# Error index=9200 img_id=9200: name 'model' is not defined
# Error index=9201 img_id=9201: name 'model' is not defined
# Error index=9202 img_id=9202: name 'model' is not defined
# Error index=9203 img_id=9203: name 'model' is not defined
# Error index=9204 img_id=9204: name 'model' is not defined
# Error index=9205 img_id=9205: name 'model' is not defined
# Error index=9206 img_id=9206: name 'model' is not defined
# Error index=9207 img_id=9207: name 'model' is not defined
# Error index=9208 img_id=9208: name 'model' is not defined
# Error index=9209 img_id=9209: name 'model' is not defined
# Error index=9210 img_id=9210: name 'model' is not defined
# Error index=9211 img_id=9211: name 'model' is not defined
# Error index=9212 img_id=9212: name 'model' is not defined
# Error index=9213 img_id=9213: name 'model' is not defined
# Error index=9214 img_id=9214: name 'model' is not defined
# Error index=9215 img_id=9215: name 'model' is not defined
